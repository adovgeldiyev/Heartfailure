# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
hd_pd = pd.read_csv("heart_disease.csv")
hd_pd.rename(columns = {'cp':'chest pain'}, inplace = True)
hd_pd
# Out:
#      age  sex  chest pain  trestbps  chol  fbs  restecg  thalach  exang  \
# 0     63    1           3       145   233    1        0      150      0
# 1     37    1           2       130   250    0        1      187      0
# 2     41    0           1       130   204    0        0      172      0
# 3     56    1           1       120   236    0        1      178      0
# 4     57    0           0       120   354    0        1      163      1
# ..   ...  ...         ...       ...   ...  ...      ...      ...    ...
# 298   57    0           0       140   241    0        1      123      1
# 299   45    1           3       110   264    0        1      132      0
# 300   68    1           0       144   193    1        1      141      0
# 301   57    1           0       130   131    0        1      115      1
# 302   57    0           1       130   236    0        0      174      0
#
#      oldpeak  slope  ca  thal  target
# 0        2.3      0   0     1       1
# ...

# %%
hd_pd.describe()
# Out:
#               age         sex  chest pain    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_pd.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
plt.figure(figsize=(12,10))
sns.heatmap(hd_pd.corr(),annot=True,cmap="magma",fmt='.2f')

# %%
target = hd_pd['target']
target_names = ['yes','no']

# %%
tdata = hd_pd.drop("target", axis=1)
feature_names = tdata.columns
tdata.head()
# Out:
#    age  sex  chest pain  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   63    1           3       145   233    1        0      150      0
# 1   37    1           2       130   250    0        1      187      0
# 2   41    0           1       130   204    0        0      172      0
# 3   56    1           1       120   236    0        1      178      0
# 4   57    0           0       120   354    0        1      163      1
#
#    oldpeak  slope  ca  thal
# 0      2.3      0   0     1
# 1      3.5      0   0     2
# 2      1.4      2   0     2
# 3      0.8      2   0     2
# 4      0.6      2   0     2

# %%
from sklearn.metrics import precision_score, recall_score, roc_auc_score, roc_curve, plot_roc_curve,plot_confusion_matrix
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(tdata, target, random_state = 42)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state = 42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.7894736842105263

# %%
from sklearn.model_selection import GridSearchCV

model = RandomForestClassifier(random_state= 101).fit(X_train,y_train)
predictionforest = model.predict(X_test)

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score

random_search = {'criterion': ['entropy', 'gini'],
               'max_depth': list(np.linspace(10, 1200, 10, dtype = int)) + [None],
               'max_features': ['auto', 'sqrt','log2', None],
               'min_samples_leaf': [4, 6, 8, 12],
               'min_samples_split': [5, 7, 10, 14],
               'n_estimators': list(np.linspace(151, 1200, 10, dtype = int))}

clf = RandomForestClassifier()
model = RandomizedSearchCV(estimator = clf, param_distributions = random_search, n_iter = 80, 
                               cv = 4, verbose= 5, random_state= 101, n_jobs = -1)
model.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 80 candidates, totalling 320 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   34.1s
# [Parallel(n_jobs=-1)]: Done 272 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 320 out of 320 | elapsed:  1.4min finished
# RandomizedSearchCV(cv=4, error_score=nan,
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     ccp_alpha=0.0,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
# ...

# %%
predictionforest = model.best_estimator_.predict(X_test)
print(confusion_matrix(y_test,predictionforest))
print(classification_report(y_test,predictionforest))
acc4 = accuracy_score(y_test,predictionforest)
# Out:
# [[27  8]
#  [ 4 37]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.82        35
#            1       0.82      0.90      0.86        41
#
#     accuracy                           0.84        76
#    macro avg       0.85      0.84      0.84        76
# weighted avg       0.84      0.84      0.84        76

# %%
from sklearn.model_selection import GridSearchCV

grid_search = {
    'criterion': [model.best_params_['criterion']],
    'max_depth': [model.best_params_['max_depth']],
    'max_features': [model.best_params_['max_features']],
    'min_samples_leaf': [model.best_params_['min_samples_leaf'] - 2, 
                         model.best_params_['min_samples_leaf'], 
                         model.best_params_['min_samples_leaf'] + 2],
    'min_samples_split': [model.best_params_['min_samples_split'] - 3, 
                          model.best_params_['min_samples_split'], 
                          model.best_params_['min_samples_split'] + 3],
    'n_estimators': [model.best_params_['n_estimators'] - 150, 
                     model.best_params_['n_estimators'] - 100, 
                     model.best_params_['n_estimators'], 
                     model.best_params_['n_estimators'] + 100, 
                     model.best_params_['n_estimators'] + 150]
}

# %%
clf1 = RandomForestClassifier()
model1 = GridSearchCV(estimator = clf1, param_grid = grid_search, 
                               cv = 4, verbose= 5, n_jobs = -1)
model1.fit(X_train,y_train)

predictionforest1 = model1.best_estimator_.predict(X_test)
print(confusion_matrix(y_test,predictionforest1))
print(classification_report(y_test,predictionforest1))
acc4 = accuracy_score(y_test,predictionforest1)
# Out:
# Fitting 4 folds for each of 45 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:   20.9s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   25.8s finished
# [[27  8]
#  [ 4 37]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.77      0.82        35
#            1       0.82      0.90      0.86        41
#
#     accuracy                           0.84        76
#    macro avg       0.85      0.84      0.84        76
# weighted avg       0.84      0.84      0.84        76

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.14995900133513784, 'ca'),
#  (0.12471809132316541, 'oldpeak'),
#  (0.10771984605460977, 'chest pain'),
#  (0.10605265792678174, 'thalach'),
#  (0.09116436270704426, 'thal'),
#  (0.08535477477828118, 'age'),
#  (0.07545678931527969, 'trestbps'),
#  (0.07386090626228475, 'chol'),
#  (0.07080710540535612, 'exang'),
#  (0.04862728752627196, 'slope'),
#  (0.03237272586020171, 'sex'),
#  (0.022854742941469913, 'restecg'),
#  (0.01105170856411567, 'fbs')]

# %%
n_nodes = []
max_depths = []

# Stats about the trees in random forest
for ind_tree in rf.estimators_:
    n_nodes.append(ind_tree.tree_.node_count)
    max_depths.append(ind_tree.tree_.max_depth)
    
print(f'Average number of nodes {int(np.mean(n_nodes))}')
print(f'Average maximum depth {int(np.mean(max_depths))}')
# Out:
# Average number of nodes 79
# Average maximum depth 9

# %%
svc=SVC(random_state = 42)
svc.fit(X_train,y_train)
svc.score(X_test,y_test)
# Out:
# 0.6973684210526315

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data

X_scaler = StandardScaler().fit(X_train)

# %%
# Loop through different k values to see which has the highest accuracy
# Note: We only use odd numbers because we don't want any ties
train_scores = []
test_scores = []
for k in range(1, 20, 2):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)
    train_score = knn.score(X_train_scaled, y_train)
    test_score = knn.score(X_test_scaled, y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)
    print(f"k: {k}, Train/Test Score: {train_score:.3f}/{test_score:.3f}")
# Out:
# k: 1, Train/Test Score: 1.000/0.803
# k: 3, Train/Test Score: 0.890/0.855
# k: 5, Train/Test Score: 0.863/0.882
# k: 7, Train/Test Score: 0.877/0.908
# k: 9, Train/Test Score: 0.850/0.882
# k: 11, Train/Test Score: 0.824/0.868
# k: 13, Train/Test Score: 0.859/0.868
# k: 15, Train/Test Score: 0.841/0.855
# k: 17, Train/Test Score: 0.846/0.868
# k: 19, Train/Test Score: 0.846/0.868

# %%
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(X_train_scaled, y_train)
print('k=13 Test Acc: %.3f' % knn.score(X_test_scaled, y_test))
# Out:
# k=13 Test Acc: 0.868

# %% [raw]
# fig = plt.figure(figsize=(10,8))
# ax = plt.gca()
# rfc_disp = plot_roc_curve(rf, X_test, y_test, ax=ax, alpha=0.8)
# knn_disp = plot_roc_curve(knn, X_test_scaled, y_test, ax=ax, alpha=0.8)
# clf_disp = plot_roc_curve(clf, X_test, y_test, ax=ax, alpha=0.8)
# svc_disp.plot(ax=ax, alpha=0.8)
# plt.plot([0,1], [0,1], color='orange', linestyle='--')
#
# plt.xticks(np.arange(0.0, 1.1, step=0.1))
# plt.xlabel("False Positive Rate", fontsize=15)
#
# plt.yticks(np.arange(0.0, 1.1, step=0.1))
# plt.ylabel("True Positive Rate", fontsize=15)
#
# plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
# plt.legend(prop={'size':13}, loc='lower right')
#
# plt.show()
# plt.show()

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {"C":[1, 5, 10],
             "gamma":[0.0001, 0.001, 0.01]}
grid = GridSearchCV(rf, param_grid, verbose = 3)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-3949096c802a> in <module>
# ----> 1 grid.fit(X_train, y_train)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     708                 return results
#     709
# --> 710             self._run_search(evaluate_candidates)
#     711
#     712         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1149     def _run_search(self, evaluate_candidates):
# ...
